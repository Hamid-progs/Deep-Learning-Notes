# %% [markdown]
# <center><p>
#   <img
#     src="https://cdn.builtin.com/cdn-cgi/image/f=auto/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/national/rnn-vs-fnn.png"
#     alt="RNN vs FNN"
#     width="700"
#   />
# </p></center>

# %%
import keras
from keras import Sequential
from keras.layers import Dense,SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(3,input_shape=(4,5)))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# 2026-08-05 14:51:11.687343: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             4 │
# ...

# %%
print(model.get_weights()[0].shape)
model.get_weights()[0]
# Out:
# (5, 3)
# array([[-0.16681343,  0.00846863, -0.80526036],
#        [ 0.1808216 ,  0.22374481, -0.7994324 ],
#        [ 0.42976135, -0.3318931 , -0.01790172],
#        [ 0.18795556,  0.6135091 , -0.18386841],
#        [ 0.3074687 , -0.25899345, -0.49156263]], dtype=float32)

# %%
print(model.get_weights()[1].shape)
model.get_weights()[1]
# Out:
# (3, 3)
# array([[-0.9005829 , -0.33151886,  0.28115067],
#        [ 0.34183303, -0.9396702 , -0.0130511 ],
#        [-0.2685156 , -0.084353  , -0.9595749 ]], dtype=float32)

# %%
print(model.get_weights()[2].shape)
model.get_weights()[2]
# Out:
# (3,)
# array([0., 0., 0.], dtype=float32)

# %%
print(model.get_weights()[3].shape)
model.get_weights()[3]
# Out:
# (3, 1)
# array([[0.4657098 ],
#        [0.33859265],
#        [0.7249366 ]], dtype=float32)

# %%
print(model.get_weights()[4].shape)
model.get_weights()[4]
# Out:
# (1,)
# array([0.], dtype=float32)

# %% [markdown]
# <p align="center">
#   <img
#     src="https://raw.githubusercontent.com/Hamid-progs/Deep-Learning-Notes/main/rnn.jpeg"
#     alt="RNN"
#     width="700"
#   />
# </p>

# %% [markdown]
# **train able parameters:**
# 1. 5x3 = 15 weight + 3 bias
# 2. 3x3 = 9 weights
# 3. 3x1 = 3 weights + 1 bias
#
# **total** = 27 weights and 4 bias
